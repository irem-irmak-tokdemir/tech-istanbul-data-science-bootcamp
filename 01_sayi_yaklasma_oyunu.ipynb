# %% [markdown]
# # program

# %%
x=72
y=int(input("Bir sayı tuttum bakalım bu sayıya yaklaşabilecek misin. Unutma verdiğin sayı bir eksiği ile çarpılıcak.Minik bir tavsiye 0-20 arası bir sayı yaz."))
sonuc=(y*y)-y
if x<sonuc :
  if sonuc-x<=10 :
    print(" Tebrikler canım iyi sayılır 50 puan aldın. Senin sayın işlemi sonucu :" , sonuc ," oldu. Benim sayım ise", x ,"idi. Aradaki fark " ,sonuc-x)
  elif sonuc-x<=50:
    print("Oldukça yaklaştın. Tekrar dene bu sever başarıcaksın. Sana bir ipucu vereyim; Senin sayının işlem sonucu: " ,sonuc," . Benim sayım ile arasındaki fark:", sonuc-x)
  else:
    print("Uheyyyy Ufak atta balıklar yesin. O ne ayol. Sapma miktarın: ",sonuc-x)
elif x>sonuc:
  if x-sonuc<=10:
    print(" Tebrikler canım iyi sayılır 50 puan aldın. Senin sayın işlemi sonucu : " , sonuc ," oldu. Benim sayım ise", x ,"idi. Aradaki fark " ,x-sonuc)
  elif x-sonuc<=50:
    print("Oldukça yaklaştın. Tekrar dene bu sever başarıcaksın. Sana bir ipucu vereyim; Senin sayının işlem sonucu: " ,sonuc," . Benim sayım ile arasındaki fark:", x-sonuc)
  else:
    print("Uheyyyy. Ufak atta balıklar yesin. O ne ayol. Sapma miktarın: ",x-sonuc)
else:
  print("Kodumu açıp sayıya mı baktın ??? Nasıl nokta atışı yaptın?? Helallll 100 puannnn")
# Out:
# Bir sayı tuttum bakalım bu sayıya yaklaşabilecek misin. Unutma verdiğin sayı bir eksiği ile çarpılıcak.Minik bir tavsiye 0-20 arası bir sayı yaz.17
# Uheyyyy Ufak atta balıklar yesin. O ne ayol. Sapma miktarın:  200
